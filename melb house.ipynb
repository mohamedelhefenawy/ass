# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
import scipy.stats as stats

# %%
df = pd.read_csv('C:/Users/7fno/Desktop/melb_data.csv')
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.isna().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         0.000000
# Bathroom         0.000000
# Car              0.004566
# Landsize         0.000000
# BuildingArea     0.474963
# YearBuilt        0.395803
# CouncilArea      0.100810
# Lattitude        0.000000
# Longtitude       0.000000
# Regionname       0.000000
# Propertycount    0.000000
# dtype: float64

# %%
pd.crosstab(df['Regionname'],df['Suburb'])
# drop suburb
df.drop(['Suburb','SellerG','CouncilArea'],axis = 1 ,inplace=True)
df
# Out:
#                 Address  Rooms Type      Price Method        Date  Distance  \
# 0          85 Turner St      2    h  1480000.0      S   3/12/2016       2.5
# 1       25 Bloomburg St      2    h  1035000.0      S   4/02/2016       2.5
# 2          5 Charles St      3    h  1465000.0     SP   4/03/2017       2.5
# 3      40 Federation La      3    h   850000.0     PI   4/03/2017       2.5
# 4           55a Park St      4    h  1600000.0     VB   4/06/2016       2.5
# ...                 ...    ...  ...        ...    ...         ...       ...
# 13575      12 Strada Cr      4    h  1245000.0      S  26/08/2017      16.7
# 13576     77 Merrett Dr      3    h  1031000.0     SP  26/08/2017       6.8
# 13577       83 Power St      3    h  1170000.0      S  26/08/2017       6.8
# 13578      96 Verdon St      4    h  2500000.0     PI  26/08/2017       6.8
# 13579        6 Agnes St      4    h  1285000.0     SP  26/08/2017       6.3
#
# ...

# %%
df.isnull().mean()
# Out:
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         0.000000
# Bathroom         0.000000
# Car              0.004566
# Landsize         0.000000
# BuildingArea     0.474963
# YearBuilt        0.395803
# Lattitude        0.000000
# Longtitude       0.000000
# Regionname       0.000000
# Propertycount    0.000000
# dtype: float64

# %%
print (df.BuildingArea.isna().mean())
print(df.YearBuilt.isna().mean())
df.drop(['BuildingArea','YearBuilt','Postcode','Address'],axis = 1 , inplace= True)
# Out:
# 0.47496318114874814
# 0.3958026509572901

# %%
df
# Out:
#        Rooms Type      Price Method        Date  Distance  Bedroom2  Bathroom  \
# 0          2    h  1480000.0      S   3/12/2016       2.5       2.0       1.0
# 1          2    h  1035000.0      S   4/02/2016       2.5       2.0       1.0
# 2          3    h  1465000.0     SP   4/03/2017       2.5       3.0       2.0
# 3          3    h   850000.0     PI   4/03/2017       2.5       3.0       2.0
# 4          4    h  1600000.0     VB   4/06/2016       2.5       3.0       1.0
# ...      ...  ...        ...    ...         ...       ...       ...       ...
# 13575      4    h  1245000.0      S  26/08/2017      16.7       4.0       2.0
# 13576      3    h  1031000.0     SP  26/08/2017       6.8       3.0       2.0
# 13577      3    h  1170000.0      S  26/08/2017       6.8       3.0       2.0
# 13578      4    h  2500000.0     PI  26/08/2017       6.8       4.0       1.0
# 13579      4    h  1285000.0     SP  26/08/2017       6.3       4.0       1.0
#
# ...

# %%
# from geopy.geocoders import ArcGIS
# nom = ArcGIS()
# nom.geocode('Northern Metropolitan')
# nom.geocode('Abbotsford')
# nom.geocode('Bloomburg')

# %%
df.groupby(['Regionname'])['Price'].mean().sort_values(ascending=False)
# Out:
# Regionname
# Southern Metropolitan         1.372963e+06
# Eastern Metropolitan          1.104080e+06
# South-Eastern Metropolitan    9.229438e+05
# Northern Metropolitan         8.981711e+05
# Western Metropolitan          8.664205e+05
# Eastern Victoria              6.999808e+05
# Northern Victoria             5.948293e+05
# Western Victoria              3.975234e+05
# Name: Price, dtype: float64

# %%
sns.barplot(df,x = 'Propertycount',y = 'Regionname')
# Out:
# <AxesSubplot: xlabel='Propertycount', ylabel='Regionname'>

# %%
df['Distance'].unique()
# Out:
# array([ 2.5, 13.5,  3.3,  6.4, 13.8, 11.1,  6.3,  5.9, 11. , 12.2, 10.5,
#         6.6,  9.7,  9.2, 13. , 13.9, 13.1, 10.8, 11.2, 10.7,  5.2, 11.8,
#        11.7,  7.8,  9. ,  3.2, 11.4,  8.9,  8.1,  9.3, 13.6,  3.4,  1.6,
#        10.3,  8.5,  7.7,  8. ,  9.4,  5.8,  3.5,  4.4, 12.1, 13.7, 14.5,
#         4.6,  7.9, 15. , 12.8,  4.2,  5.6,  7.5,  6.2,  7.4,  8.7,  2.8,
#         4.1,  6.9, 14.6,  8.4,  2.3,  5.5, 11.5, 14.7,  2.6,  9.9,  3.8,
#         4.5,  8.8,  2.1,  1.2,  6.1, 12.6, 13.3,  6.5, 14.9,  1.9,  5.1,
#         7. ,  9.1,  9.5,  1.8,  1.5,  9.8, 12.4, 10.6,  8.2, 10.9, 10.4,
#        14. , 12.5,  5.3, 12.7,  3.7,  3. ,  5.7, 10.2, 23.2, 17.3, 35.2,
#        25. , 16.1,  4. , 14.8, 17.9,  3.6,  6.7, 20.6, 34.7, 23. , 24.7,
#        21.8, 22.2, 14.3, 25.9, 18. , 19.6, 15.4, 38. , 36.9, 45.9, 12.9,
#         7.3, 32.3, 45.2, 16. , 12.3, 15.5,  5.4, 25.2, 16.3,  4.3, 31.7,
#        17.2, 16.2, 21.5, 14.2, 34.1, 12. ,  2.4, 21.3, 23.8, 23.5, 15.2,
# ...

# %%
print(df['Propertycount'].nunique())
# Out:
# 311

# %% [markdown]
# Feature Engineering

# %%
X = df.drop(['Price'],axis = 1)
y = df.Price
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .20,random_state=40)

# %%
X_train.isna().mean()
# Out:
# Rooms            0.000000
# Type             0.000000
# Method           0.000000
# Date             0.000000
# Distance         0.000000
# Bedroom2         0.000000
# Bathroom         0.000000
# Car              0.004878
# Landsize         0.000000
# Lattitude        0.000000
# Longtitude       0.000000
# Regionname       0.000000
# Propertycount    0.000000
# dtype: float64

# %%
def impute_na(df,var,mean_median):
    return df[var].fillna(mean_median)

# %%
mean = df['Car'].mean()
median = df['Car'].median()
print(mean)
print(median)
# Out:
# 1.6100754549489569
# 2.0

# %%
X_train['mean_Car'] = impute_na(X_train,'Car',mean)
X_train['median_car'] = impute_na(X_train,'Car',median)
X_train.isna().mean()
# Out:
# Rooms            0.000000
# Type             0.000000
# Method           0.000000
# Date             0.000000
# Distance         0.000000
# Bedroom2         0.000000
# Bathroom         0.000000
# Car              0.004878
# Landsize         0.000000
# Lattitude        0.000000
# Longtitude       0.000000
# Regionname       0.000000
# Propertycount    0.000000
# mean_Car         0.000000
# median_car       0.000000
# dtype: float64

# %%
fig = plt.figure()
ax = plt.subplot()
X_train["Car"].plot(kind = 'kde',ax = ax,color = 'yellow')
X_train['mean_Car'].plot(kind = 'kde',ax = ax,color = 'green')
X_train['median_car'].plot(kind = 'kde',ax= ax,color = 'red')
lines,lables = ax.get_legend_handles_labels()
ax.legend(lines,lables)

# %%
print(X_train['Car'].var())
print(X_train['mean_Car'].var())
print(X_train['median_car'].var())
# The best variance is Median
# Out:
# 0.9342267712905219
# 0.9296687289972726
# 0.9304056940524624

# %%
X_train
# Out:
#        Rooms Type Method        Date  Distance  Bedroom2  Bathroom  Car  \
# 8829       3    h      S   1/07/2017      13.8       3.0       1.0  2.0
# 3977       2    u      S   4/03/2017       2.8       2.0       2.0  1.0
# 5819       2    u     PI  14/05/2016       6.1       2.0       1.0  1.0
# 6990       3    h     VB  17/09/2016       7.5       3.0       1.0  2.0
# 13182      3    h      S  23/09/2017      38.0       3.0       1.0  1.0
# ...      ...  ...    ...         ...       ...       ...       ...  ...
# 11532      3    h      S  15/07/2017      21.1       3.0       2.0  0.0
# 5426       2    h     SP  27/11/2016       2.6       2.0       1.0  0.0
# 7608       4    h     VB  20/05/2017       5.2       4.0       3.0  2.0
# 11256      3    h     VB  12/08/2017      25.2       3.0       2.0  2.0
# 11590      4    h     SP  22/07/2017      39.0       4.0       2.0  2.0
#
#        Landsize  Lattitude  Longtitude                  Regionname  \
# ...

# %%
X_train['Car'] = X_train['median_car'].copy()
X_test['Car'] = impute_na(X_test,'Car',median)

X_train.isnull().mean()
X_test.isna().mean()
X_train.drop(['median_car','mean_Car'],axis = 1,inplace= True)
X_train
# NO NANS#
# Out:
#        Rooms Type Method        Date  Distance  Bedroom2  Bathroom  Car  \
# 8829       3    h      S   1/07/2017      13.8       3.0       1.0  2.0
# 3977       2    u      S   4/03/2017       2.8       2.0       2.0  1.0
# 5819       2    u     PI  14/05/2016       6.1       2.0       1.0  1.0
# 6990       3    h     VB  17/09/2016       7.5       3.0       1.0  2.0
# 13182      3    h      S  23/09/2017      38.0       3.0       1.0  1.0
# ...      ...  ...    ...         ...       ...       ...       ...  ...
# 11532      3    h      S  15/07/2017      21.1       3.0       2.0  0.0
# 5426       2    h     SP  27/11/2016       2.6       2.0       1.0  0.0
# 7608       4    h     VB  20/05/2017       5.2       4.0       3.0  2.0
# 11256      3    h     VB  12/08/2017      25.2       3.0       2.0  2.0
# 11590      4    h     SP  22/07/2017      39.0       4.0       2.0  2.0
#
#        Landsize  Lattitude  Longtitude                  Regionname  \
# ...

# %%
X_test.isna().any()
# Out:
# Rooms            False
# Type             False
# Method           False
# Date             False
# Distance         False
# Bedroom2         False
# Bathroom         False
# Car              False
# Landsize         False
# Lattitude        False
# Longtitude       False
# Regionname       False
# Propertycount    False
# dtype: bool

# %%
X_train.Regionname.value_counts()
# Out:
# Southern Metropolitan         3754
# Northern Metropolitan         3118
# Western Metropolitan          2367
# Eastern Metropolitan          1168
# South-Eastern Metropolitan     353
# Eastern Victoria                42
# Northern Victoria               33
# Western Victoria                29
# Name: Regionname, dtype: int64

# %%
X_train['Regionname']=X_train['Regionname'].replace(['Eastern Victoria','Northern Victoria','Western Victoria'],'Victoria')
X_test['Regionname']= X_test['Regionname'].replace(['Eastern Victoria','Northern Victoria','Western Victoria'],'Victoria')
X_train.Regionname.value_counts()
# Out:
# Southern Metropolitan         3754
# Northern Metropolitan         3118
# Western Metropolitan          2367
# Eastern Metropolitan          1168
# South-Eastern Metropolitan     353
# Victoria                       104
# Name: Regionname, dtype: int64

# %%
from category_encoders.target_encoder import TargetEncoder
target = TargetEncoder(cols = ['Method','Regionname','Type']).fit(X_train,y_train)
hi= target.transform(X_train)
hii = target.transform(X_test)
hi
# Out:
# c:\Users\7fno\AppData\Local\Programs\Python\Python39\lib\site-packages\category_encoders\target_encoder.py:122: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# c:\Users\7fno\AppData\Local\Programs\Python\Python39\lib\site-packages\category_encoders\target_encoder.py:127: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
#        Rooms          Type        Method        Date  Distance  Bedroom2  \
# 8829       3  1.244939e+06  1.090100e+06   1/07/2017      13.8       3.0
# 3977       2  6.055469e+05  1.090100e+06   4/03/2017       2.8       2.0
# 5819       2  6.055469e+05  1.146869e+06  14/05/2016       6.1       2.0
# ...

# %%
X_train= hi.copy()
X_test = hii.copy()

# %%
def diagnostic_plots(data, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.distplot(data[variable],bins=30)
    plt.title('Histogram')

    # Q-Q plot
    # plt.subplot(1, 3, 2)
    # stats.probplot(data[variable], dist="norm", plot=plt,)

    # # boxplot
    # plt.subplot(1, 3, 3)
    # sns.boxplot(y = data[variable])
    # plt.title('Boxplot')
    
    plt.show()

# %%
diagnostic_plots(X_train,'Propertycount')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\3160698751.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
X_train.Propertycount = X_train.Propertycount**(1/1.5)

# %%
diagnostic_plots(X_train,'Propertycount')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\3160698751.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
diagnostic_plots(X_train,'Distance')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\3160698751.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
X_train['Distance'] = X_train['Distance']**(1/2)
diagnostic_plots(X_train,'Distance')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\3160698751.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
diagnostic_plots(X_train,'Landsize')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\3160698751.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
from sklearn.preprocessing import KBinsDiscretizer
disc = KBinsDiscretizer(  n_bins=10,strategy='quantile',encode='ordinal')
disc.fit(X_train[['Distance','Landsize']])
# Out:
# c:\Users\7fno\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_discretization.py:291: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 1 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# KBinsDiscretizer(encode='ordinal', n_bins=10)

# %%
X_train[['Distance','Landsize']] = disc.transform(X_train[['Distance','Landsize']])
X_train
X_train = pd.DataFrame(X_train)

# %%
X_train
# Out:
#        Rooms          Type        Method        Date  Distance  Bedroom2  \
# 8829       3  1.244939e+06  1.090100e+06   1/07/2017       8.0       3.0
# 3977       2  6.055469e+05  1.090100e+06   4/03/2017       0.0       2.0
# 5819       2  6.055469e+05  1.146869e+06  14/05/2016       2.0       2.0
# 6990       3  1.244939e+06  1.161547e+06  17/09/2016       3.0       3.0
# 13182      3  1.244939e+06  1.090100e+06  23/09/2017       9.0       3.0
# ...      ...           ...           ...         ...       ...       ...
# 11532      3  1.244939e+06  1.090100e+06  15/07/2017       9.0       3.0
# 5426       2  1.244939e+06  8.956411e+05  27/11/2016       0.0       2.0
# 7608       4  1.244939e+06  1.161547e+06  20/05/2017       1.0       4.0
# 11256      3  1.244939e+06  1.161547e+06  12/08/2017       9.0       3.0
# 11590      4  1.244939e+06  8.956411e+05  22/07/2017       9.0       4.0
#
#        Bathroom  Car  Landsize  Lattitude  Longtitude    Regionname  \
# ...

# %%
X_test[['Distance','Landsize']] = disc.transform(X_test[['Distance','Landsize']])
X_test 
X_test = pd.DataFrame(X_test)

# %%
# for var in ['Distance','Propertycount','Landsize']:
#     t1 = X_train.groupby([var])[var].count() / len(X_train[var])
#     t2 = X_test.groupby([var])[var].count() / len(X_train[var])

#     tmp = pd.concat([t1, t2], axis=1)
#     tmp.columns = ['train', 'test']
#     tmp.plot.bar()
#     plt.xticks(rotation=0)
#     plt.ylabel('Number of observations per bin')

# %%
def diagnostics_plots(data, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.distplot(data[variable],bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 2)
    stats.probplot(data[variable], dist="norm", plot=plt,)

    # boxplot
    plt.subplot(1, 3, 3)
    sns.boxplot(y = data[variable])
    plt.title('Boxplot')
    
    plt.show()

# %%
diagnostics_plots(X_train,'Bathroom')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\2557863963.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
from sklearn.preprocessing import KBinsDiscretizer
disc = KBinsDiscretizer(  n_bins=5,strategy='quantile',encode='ordinal')
disc.fit(X_train[['Car','Rooms',"Bathroom",'Bedroom2']])
# Out:
# c:\Users\7fno\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_discretization.py:291: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# c:\Users\7fno\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_discretization.py:291: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 1 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# c:\Users\7fno\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_discretization.py:291: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 2 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# ...

# %%
X_train[['Car','Rooms',"Bathroom",'Bedroom2']] = disc.transform(X_train[['Car','Rooms',"Bathroom",'Bedroom2']])
X_test[['Car','Rooms',"Bathroom",'Bedroom2']] = disc.transform(X_test[['Car','Rooms',"Bathroom",'Bedroom2']])

# %%
for var in ['Car','Rooms',"Bathroom",'Bedroom2']:
    t1 = X_train.groupby([var])[var].count() / len(X_train[var])
    t2 = X_test.groupby([var])[var].count() / len(X_train[var])

    tmp = pd.concat([t1, t2], axis=1)
    tmp.columns = ['train', 'test']
    tmp.plot.bar()
    plt.xticks(rotation=0)
    plt.ylabel('Number of observations per bin')

# %%
X_train
X_test
# Out:
#        Rooms          Type        Method        Date  Distance  Bedroom2  \
# 9959     1.0  1.244939e+06  1.090100e+06  24/06/2017       9.0       1.0
# 5888     3.0  1.244939e+06  1.090100e+06   7/05/2016       9.0       2.0
# 1218     2.0  1.244939e+06  1.090100e+06  17/09/2016       9.0       2.0
# 3585     1.0  6.055469e+05  1.146869e+06   4/03/2017       9.0       1.0
# 10419    3.0  1.244939e+06  1.090100e+06  27/05/2017       9.0       3.0
# ...      ...           ...           ...         ...       ...       ...
# 11671    1.0  6.055469e+05  1.146869e+06  22/07/2017       9.0       1.0
# 9259     1.0  1.244939e+06  1.090100e+06   3/06/2017       0.0       1.0
# 13142    2.0  1.244939e+06  1.146869e+06  23/09/2017       9.0       2.0
# 9763     3.0  1.244939e+06  1.090100e+06  17/06/2017       9.0       3.0
# 4569     2.0  1.244939e+06  1.090100e+06  27/11/2016       9.0       2.0
#
#        Bathroom  Car  Landsize  Lattitude  Longtitude    Regionname  \
# ...

# %%
X_train.drop(['Date','Propertycount'],axis = 1,inplace = True)
X_test.drop(['Date','Propertycount'],axis = 1,inplace = True)

# %%
X_train.dtypes
# Out:
# Rooms         float64
# Type          float64
# Method        float64
# Distance      float64
# Bedroom2      float64
# Bathroom      float64
# Car           float64
# Landsize      float64
# Lattitude     float64
# Longtitude    float64
# Regionname    float64
# dtype: object

# %%
diagnostics_plots(X_train,'Lattitude')
# Out:
# C:\Users\7fno\AppData\Local\Temp\ipykernel_7656\2557863963.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[variable],bins=30)

# %%
fig = plt.figure(figsize=(12,7))
corr = pd.concat ([X_train,y_train],axis = 1)
cormat = corr.corr()
sns.heatmap(cormat,annot=True)
# Out:
# <AxesSubplot: >

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error

rf = RandomForestRegressor(max_depth=60, max_features=6, min_samples_leaf=5,
                           min_samples_split=6, n_estimators=60, oob_score=True,
                           max_leaf_nodes=500,random_state = 101).fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,y_pred)))
print(r2_score(y_test,y_pred))
# Out:
# 365690.8053466271
# 0.6421471300897486

# %%
train_score = rf.score(X_train, y_train)
oob_score = rf.oob_score_
Adjusted_R2_train = 1 - (1-rf.score(X_train, y_train))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
Adjusted_R2_test = 1 - (1-rf.score(X_test, y_test))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

print('Train Adjusted R2: %', Adjusted_R2_train*100)
print('Test Adjusted R2: %', Adjusted_R2_test*100)
print('OOB Score: %', oob_score*100)
# Out:
# Train Adjusted R2: % 85.26731376018908
# Test Adjusted R2: % 64.06913676751729
# OOB Score: % 77.33052596245419
